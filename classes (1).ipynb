# %%
import math as m
import random as r

class SakClass:
    
    def __init__(self, letters):
        self.letters = letters
    
    
    def getletters(self):
        
        i=0
        player_letters = []
        keys = list(self.letters)
        
        for i in range(6):
            temp = r.randint(0,24)
            key = keys[temp]
            player_letters.append(key)
        
        return player_letters
            
          
    
    def putbackletters():
        pass
    
    def randomize_sak():
        pass

    
class Player:
    
    def __init__(self, name):
        self.points = 0
        self.letters = []
        self.name = name
    
    
    def __repr__(self):
        return f'Class: {self.__class__}, Name: {self.name}, Points: {self.points}'

class Human(Player):
    
    def __init__(self, name):
        self.points = 0
        self.letters = []
        self.name = name
        
    
class Computer(Player):
    
    def __init__(self):
        self.points = 0
        self.letters = []
        self.name = 'Computer'
    
    
class Game:
    pass


def initialize_letters():
    
    letters = {
            "Α": [12, 1],
            "Β": [1, 3],
            "Γ": [2, 4],
            "Δ": [2, 4],
            "Ε": [8, 1],
            "Ζ": [1, 10],
            "Η": [7, 1],
            "Θ": [1, 10],
            "Ι": [8, 1],
            "Κ": [4, 2],
            "Λ": [3, 3],
            "Μ": [3, 3],
            "Ν": [6, 1],
            "Ξ": [1, 10],
            "Ο": [9, 1],
            "Π": [4, 2],
            "Ρ": [5, 2],
            "Σ": [7, 1],
            "Τ": [8, 1],
            "Υ": [4, 2],
            "Φ": [1, 8],
            "Χ": [1, 8],
            "Ψ": [1, 10],
            "Ω": [3, 3],
            "Blank": [2, 0]
        }
    
    return letters


def main():
    
    letters = initialize_letters()
    sakoulaki = SakClass(letters)
    human = Human('Kostas')
    keys = list(letters)
    human.letters = sakoulaki.getletters()
    print(human.letters)
    
    
    
if __name__ == "__main__":
    main()
# Out:
# ['Ο', 'Τ', 'Κ', 'Σ', 'Η', 'Μ']
